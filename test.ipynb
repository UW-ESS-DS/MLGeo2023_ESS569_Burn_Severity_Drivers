# %%
import numpy as np
import scipy.stats
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot  as plt
# import scikit-learn as skl

# %%
df = pd.read_csv("data/df_for_analysis_ESS569.csv")
df
# Out:
#       Unnamed: 0  RBR           X          Y  AET_1981_2010  \
# 0              2  -37 -121.171368  42.875915     511.204498
# 1              4   28 -121.169751  42.875915     505.196411
# 2              5   15 -121.168943  42.875915     501.738190
# 3              6   53 -121.168134  42.875915     501.738190
# 4              7   24 -121.167326  42.875915     500.982483
# ...          ...  ...         ...        ...            ...
# 1820        1870  146 -121.174602  42.767578     502.809448
# 1821        1871  106 -121.173794  42.767578     502.809448
# 1822        1872   88 -121.172985  42.767578     503.752472
# 1823        1873   62 -121.172177  42.767578     503.474762
# 1824        1874  125 -121.171368  42.767578     504.481323
#
#       dist_streams_wetlands       ESI       FRS   T_max_bpd  pct_canopy_cover  \
# 0                590.118835  0.286460  0.747711  300.200012         36.245998
# 1                593.939331  0.286168  0.652768  300.200012         29.762400
# ...

# %%
df.keys()
# Out:
# Index(['Unnamed: 0', 'RBR', 'X', 'Y', 'AET_1981_2010', 'dist_streams_wetlands',
#        'ESI', 'FRS', 'T_max_bpd', 'pct_canopy_cover', 'canopy_rumple',
#        'pctl_25_canopy_height', 'pctl_95_canopy_height', 'Pct_1_tree_clumps',
#        'Pct_2_4_tree_clumps', 'Pct_5_9_tree_clumps', 'Pct_gteq10_tree_clumps',
#        'topo_aspect', 'topo_curvature_45', 'topo_plan_curvature',
#        'topo_slope_135', 'topo_SRI', 'topo_SRI_270', 'topo_TPI_4000',
#        'topo_TPI_500', 'SCF', 'wind_northsouthness', 'Rx', 'EVT_PP'],
#       dtype='object')

# %%
plt.hist(df['Rx'], 2)
# Out:
# (array([ 289., 1536.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
plt.scatter(df['Rx'], df['RBR'])
